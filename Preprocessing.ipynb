# %% [markdown]
# ## Step 1

# %%
import pandas as pd
import re

# Load the Excel file
df = pd.read_excel("/content/Secod_File.xlsx", sheet_name="Customer and Purchase")

def extract_specific_cases(cell):
    if pd.isna(cell):
        return [None, None, None]

    text = str(cell).upper().strip()

    # --- Case 1: "1+1 / 1 ADET" ---
    match_case1 = re.match(r'^\s*([\d\+]+)\s*/\s*(\d+)\s*ADET\s*$', text)
    if match_case1:
        return [f"{match_case1.group(1)} {match_case1.group(2)}", None, None]

    # --- Case 3: "1+1 / 2 ADT" (ADT instead of ADET) ---
    match_case3 = re.match(r'^\s*([\d\+]+)\s*/\s*(\d+)\s*ADT\s*$', text)
    if match_case3:
        return [f"{match_case3.group(1)} {match_case3.group(2)}", None, None]

    # --- Case 2: multiple matches like "1+1 2 ADET / 1 ADET 1+0 / 1 ADET 2+1" ---
    match_case2 = re.findall(r'([\d\+]+)\s+(\d+)\s*ADET|(\d+)\s*ADET\s*([\d\+]+)', text)
    results = []
    for part in match_case2:
        if part[0] and part[1]:  # e.g., 1+1 2 ADET
            results.append(f"{part[0]} {part[1]}")
        elif part[2] and part[3]:  # e.g., 1 ADET 1+0
            results.append(f"{part[3]} {part[2]}")

    return results[:3] + [None] * (3 - len(results))

# Apply to the column
df[['type a', 'type b', 'type c']] = df['Type of Apartment Purchased'].apply(extract_specific_cases).apply(pd.Series)

# Final dataframe
final_df = df[['Customer Name', 'Type of Apartment Purchased', 'Number of Apartment Purchased', 'type a', 'type b', 'type c']]

# Save the result
final_df.to_excel("Refined_Apartment_type.xlsx", index=False)

print("✅ Saved to 'Refined_Apartment_type.xlsx'")
# Out:
# ✅ Saved to 'Refined_Apartment_type.xlsx'

# %%
df = pd.read_excel("/content/Refined_Apartment_type.xlsx")
df
# Out:
#             Customer Name             Type of Apartment Purchased  \
# 0            HALİL GEÇİCİ                      1+1     /   1 ADET
# 1    NESLİŞAH İSTENCİOĞLU                      1+1    /    1 ADET
# 2              OLCAY ORUÇ                         1+1    / 1 ADET
# 3            SEHER YALÇIN  1+1    2 ADET / 1 ADET 1+0 /1 ADET 2+1
# 4              SEMA AKÇIL                         1+1  /  1  ADET
# ..                    ...                                     ...
# 148            GÜVEN ATAR                             1+1 /1 ADET
# 149        HÜSNÜ AYDINALP                  1 ADET1+1 / 1 ADET 2+1
# 150     JAROSLAW WOJCIECH                              1 ADET 1+1
# 151     ROZA JOWITA ORZEL                              1 ADET 1+0
# 152       MEHRDAD RANJBAR                              1 ADET 1+0
#
#      Number of Apartment Purchased type a type b type c
# 0                              1.0  1+1 1    NaN    NaN
# 1                              1.0  1+1 1    NaN    NaN
# 2                              1.0  1+1 1    NaN    NaN
# 3                              4.0  1+1 2  1+0 1  2+1 1
# 4                              1.0  1+1 1    NaN    NaN
# ..                             ...    ...    ...    ...
# 148                            1.0  1+1 1    NaN    NaN
# 149                            2.0  1+1 1  2+1 1    NaN
# 150                            NaN  1+1 1    NaN    NaN
# 151                            NaN  1+0 1    NaN    NaN
# 152                            NaN  1+0 1    NaN    NaN
#
# [153 rows x 6 columns]

# %% [markdown]
# # Step 2

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel("/content/Refined_Apartment_type.xlsx")

# Fill in '1:1 1' to 'type a' if 'Type of Apartment Purchased' is empty and Number > 0
for index, row in df.iterrows():
    type_of_apartment = row.get("Type of Apartment Purchased")
    num_apartments = row.get("Number of Apartment Purchased")

    # Check condition: Type is empty and Number > 0
    if pd.isna(type_of_apartment) and pd.notna(num_apartments) and num_apartments > 0:
        df.at[index, "type a"] = "1+1 1"

# Save the updated DataFrame
df.to_excel("Refined_Type.xlsx", index=False)

print("✅ Done! File saved as 'Refined_Type.xlsx'")
# Out:
# ✅ Done! File saved as 'Refined_Type.xlsx'

# %%
df = pd.read_excel("/content/Refined_Type.xlsx")
df
# Out:
#             Customer Name             Type of Apartment Purchased  \
# 0            HALİL GEÇİCİ                      1+1     /   1 ADET
# 1    NESLİŞAH İSTENCİOĞLU                      1+1    /    1 ADET
# 2              OLCAY ORUÇ                         1+1    / 1 ADET
# 3            SEHER YALÇIN  1+1    2 ADET / 1 ADET 1+0 /1 ADET 2+1
# 4              SEMA AKÇIL                         1+1  /  1  ADET
# ..                    ...                                     ...
# 148            GÜVEN ATAR                             1+1 /1 ADET
# 149        HÜSNÜ AYDINALP                  1 ADET1+1 / 1 ADET 2+1
# 150     JAROSLAW WOJCIECH                              1 ADET 1+1
# 151     ROZA JOWITA ORZEL                              1 ADET 1+0
# 152       MEHRDAD RANJBAR                              1 ADET 1+0
#
#      Number of Apartment Purchased type a type b type c
# 0                              1.0  1+1 1    NaN    NaN
# 1                              1.0  1+1 1    NaN    NaN
# 2                              1.0  1+1 1    NaN    NaN
# 3                              4.0  1+1 2  1+0 1  2+1 1
# 4                              1.0  1+1 1    NaN    NaN
# ..                             ...    ...    ...    ...
# 148                            1.0  1+1 1    NaN    NaN
# 149                            2.0  1+1 1  2+1 1    NaN
# 150                            NaN  1+1 1    NaN    NaN
# 151                            NaN  1+0 1    NaN    NaN
# 152                            NaN  1+0 1    NaN    NaN
#
# [153 rows x 6 columns]

# %% [markdown]
# # Step 3

# %%
import pandas as pd
import re

# Load the Excel file
df = pd.read_excel("/content/Refined_Type.xlsx")

# Columns to expand
expand_cols = ['type a', 'type b', 'type c']

# Parse the value and count from cells like '1+1 2'
def parse_value(cell):
    if pd.isna(cell):
        return None, 0
    match = re.match(r"(.+?)\s+(\d+)", str(cell).strip())
    if match:
        return match.group(1).strip(), int(match.group(2))
    else:
        return str(cell).strip(), 1  # If no count, assume 1

expanded_rows = []

for _, row in df.iterrows():
    values = {}
    repeat_counts = []

    # Parse type columns and get counts
    for col in expand_cols:
        val, count = parse_value(row[col])
        values[col] = (val, count)
        repeat_counts.append(count)

    # Ensure at least one repetition even if all counts are zero
    max_repeat = max(repeat_counts) if max(repeat_counts) > 0 else 1

    # Repeat rows accordingly
    for i in range(max_repeat):
        new_row = row.copy()
        for col in expand_cols:
            val, count = values[col]
            if count == 0:
                # Column was empty, keep empty string
                new_row[col] = ''
            else:
                # If current iteration is less than count, put val + ' 1'
                if i < count:
                    new_row[col] = f"{val} 1"
                else:
                    # Beyond count, leave empty
                    new_row[col] = ''
        expanded_rows.append(new_row)

# Create expanded DataFrame
expanded_df = pd.DataFrame(expanded_rows)

# If you want to **add final expanded rows** to original data as well:
# final_df = pd.concat([df, expanded_df], ignore_index=True)
# Otherwise just use expanded_df

expanded_df.to_excel("final_expanded_output.xlsx", index=False)

print("✅ Done! Output saved to 'final_expanded_output.xlsx'")
# Out:
# ✅ Done! Output saved to 'final_expanded_output.xlsx'

# %%
df = pd.read_excel("/content/final_expanded_output.xlsx")
df
# Out:
#             Customer Name             Type of Apartment Purchased  \
# 0            HALİL GEÇİCİ                      1+1     /   1 ADET
# 1    NESLİŞAH İSTENCİOĞLU                      1+1    /    1 ADET
# 2              OLCAY ORUÇ                         1+1    / 1 ADET
# 3            SEHER YALÇIN  1+1    2 ADET / 1 ADET 1+0 /1 ADET 2+1
# 4            SEHER YALÇIN  1+1    2 ADET / 1 ADET 1+0 /1 ADET 2+1
# ..                    ...                                     ...
# 279            GÜVEN ATAR                             1+1 /1 ADET
# 280        HÜSNÜ AYDINALP                  1 ADET1+1 / 1 ADET 2+1
# 281     JAROSLAW WOJCIECH                              1 ADET 1+1
# 282     ROZA JOWITA ORZEL                              1 ADET 1+0
# 283       MEHRDAD RANJBAR                              1 ADET 1+0
#
#      Number of Apartment Purchased type a type b type c
# 0                              1.0  1+1 1    NaN    NaN
# 1                              1.0  1+1 1    NaN    NaN
# 2                              1.0  1+1 1    NaN    NaN
# 3                              4.0  1+1 1  1+0 1  2+1 1
# 4                              4.0  1+1 1    NaN    NaN
# ..                             ...    ...    ...    ...
# 279                            1.0  1+1 1    NaN    NaN
# 280                            2.0  1+1 1  2+1 1    NaN
# 281                            NaN  1+1 1    NaN    NaN
# 282                            NaN  1+0 1    NaN    NaN
# 283                            NaN  1+0 1    NaN    NaN
#
# [284 rows x 6 columns]

# %% [markdown]
# # Step 4

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel("/content/final_expanded_output.xlsx")

# Fill NaN with empty strings
df[['type a', 'type b', 'type c']] = df[['type a', 'type b', 'type c']].fillna('')

# Condition 1: 'type a' == '1+1 1'
cond1 = df['type a'] == '1+1 1'
df_cond1 = df[cond1].copy()
df_cond1['Type of Apartment'] = '1+1 1'
df_cond1['Number of Rooms'] = 1

# Condition 2: ANY of 'type a', 'type b', 'type c' == '1+0 1'
cond2 = (df['type a'] == '1+0 1') | (df['type b'] == '1+0 1') | (df['type c'] == '1+0 1')
df_cond2 = df[cond2].copy()
df_cond2['Type of Apartment'] = '1+0 1'
df_cond2['Number of Rooms'] = 1

# Condition 3: ANY of 'type a', 'type b', 'type c' == '2+1 1'
cond3 = (df['type a'] == '2+1 1') | (df['type b'] == '2+1 1') | (df['type c'] == '2+1 1')
df_cond3 = df[cond3].copy()
df_cond3['Type of Apartment'] = '2+1 1'
df_cond3['Number of Rooms'] = 2

# Keep only required columns
cols_to_keep = ['Customer Name', 'Number of Rooms', 'Type of Apartment']

df_cond1 = df_cond1[cols_to_keep]
df_cond2 = df_cond2[cols_to_keep]
df_cond3 = df_cond3[cols_to_keep]

# Save to Excel files
df_cond1.to_excel("Block_A.xlsx", index=False)
df_cond2.to_excel("Block_B.xlsx", index=False)
df_cond3.to_excel("Block_C.xlsx", index=False)

print("Files saved: type_1.xlsx, type_2.xlsx, and type_3.xlsx with final type and number of rooms.")
# Out:
# Files saved: type_1.xlsx, type_2.xlsx, and type_3.xlsx with final type and number of rooms.

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel("/content/final_expanded_output.xlsx")

# Fill NaN with empty strings
df[['type a', 'type b', 'type c']] = df[['type a', 'type b', 'type c']].fillna('')

# Condition 1: 'type a' == '1+1 1'
cond1 = df['type a'] == '1+1 1'
df_cond1 = df[cond1].copy()
df_cond1['Type of Apartment'] = '1+1 1'
df_cond1['Number of Rooms'] = 1

# Condition 2: ANY of 'type a', 'type b', 'type c' == '1+0 1'
cond2 = (df['type a'] == '1+0 1') | (df['type b'] == '1+0 1') | (df['type c'] == '1+0 1')
df_cond2 = df[cond2].copy()
df_cond2['Type of Apartment'] = '1+0 1'
df_cond2['Number of Rooms'] = 1

# Condition 3: ANY of 'type a', 'type b', 'type c' == '2+1 1'
cond3 = (df['type a'] == '2+1 1') | (df['type b'] == '2+1 1') | (df['type c'] == '2+1 1')
df_cond3 = df[cond3].copy()
df_cond3['Type of Apartment'] = '2+1 1'
df_cond3['Number of Rooms'] = 2

# Add Flat ID Name column (1 to N)
df_cond1['Flat ID Name'] = range(1, len(df_cond1) + 1)
df_cond2['Flat ID Name'] = range(1, len(df_cond2) + 1)
df_cond3['Flat ID Name'] = range(1, len(df_cond3) + 1)

# Keep only required columns
cols_to_keep = ['Flat ID Name', 'Customer Name', 'Number of Rooms', 'Type of Apartment']
df_cond1 = df_cond1[cols_to_keep]
df_cond2 = df_cond2[cols_to_keep]
df_cond3 = df_cond3[cols_to_keep]

# Save to Excel files
df_cond1.to_excel("Block_A.xlsx", index=False)
df_cond2.to_excel("Block_B.xlsx", index=False)
df_cond3.to_excel("Block_C.xlsx", index=False)

print("Files saved: Block_A.xlsx, Block_B.xlsx, and Block_C.xlsx with Flat ID Name added.")
# Out:
# Files saved: Block_A.xlsx, Block_B.xlsx, and Block_C.xlsx with Flat ID Name added.

# %%
df = pd.read_excel("/content/Block_A.xlsx")
df
# Out:
#      Flat ID Name         Customer Name  Number of Rooms Type of Apartment
# 0               1          HALİL GEÇİCİ                1             1+1 1
# 1               2  NESLİŞAH İSTENCİOĞLU                1             1+1 1
# 2               3            OLCAY ORUÇ                1             1+1 1
# 3               4          SEHER YALÇIN                1             1+1 1
# 4               5          SEHER YALÇIN                1             1+1 1
# ..            ...                   ...              ...               ...
# 260           261           ŞENOL ÇAKIR                1             1+1 1
# 261           262     AMELİA KATAR ZYLA                1             1+1 1
# 262           263            GÜVEN ATAR                1             1+1 1
# 263           264        HÜSNÜ AYDINALP                1             1+1 1
# 264           265     JAROSLAW WOJCIECH                1             1+1 1
#
# [265 rows x 4 columns]

# %%
df = pd.read_excel("/content/Block_B.xlsx")
df
# Out:
#     Flat ID Name                          Customer Name  Number of Rooms  \
# 0              1                           SEHER YALÇIN                1
# 1              2                            HATİCE OKÇU                1
# 2              3                          HICHAM HALLOU                1
# 3              4                          HICHAM HALLOU                1
# 4              5                          HICHAM HALLOU                1
# 5              6                          HICHAM HALLOU                1
# 6              7                          HICHAM HALLOU                1
# 7              8                          HICHAM HALLOU                1
# 8              9                     İSMAİL HAKKI ÖNDER                1
# 9             10  SEDA ÇERÇİZ VE ASİYE SERAP KARASULAR                 1
# 10            11                       AZİZ UĞUR ÇAĞLAR                1
# 11            12                          ÇİĞDEM ÇAĞLAR                1
# 12            13                          BEYHAN SEZGİN                1
# 13            14                         BAHADIR TIKNAS                1
# 14            15                            VELİ BAYDUR                1
# 15            16                            ÖZTÜRK AVCI                1
# 16            17                            ÖZTÜRK AVCI                1
# 17            18                      MAR USZ JAN DANAK                1
# 18            19                      MAR USZ JAN DANAK                1
# 19            20                      MAR USZ JAN DANAK                1
# 20            21                            SİBEL ALGÜL                1
# 21            22                      ROZA JOWITA ORZEL                1
# 22            23                        MEHRDAD RANJBAR                1
#
#    Type of Apartment
# 0              1+0 1
# 1              1+0 1
# 2              1+0 1
# 3              1+0 1
# 4              1+0 1
# 5              1+0 1
# 6              1+0 1
# 7              1+0 1
# 8              1+0 1
# 9              1+0 1
# 10             1+0 1
# 11             1+0 1
# 12             1+0 1
# 13             1+0 1
# 14             1+0 1
# 15             1+0 1
# 16             1+0 1
# 17             1+0 1
# 18             1+0 1
# 19             1+0 1
# 20             1+0 1
# 21             1+0 1
# 22             1+0 1

# %%
df = pd.read_excel("/content/Block_C.xlsx")
df
# Out:
#    Flat ID Name   Customer Name  Number of Rooms Type of Apartment
# 0             1    SEHER YALÇIN                2             2+1 1
# 1             2  HÜSNÜ AYDINALP                2             2+1 1

# %% [markdown]
# # Final Output

# %%
import pandas as pd
import random

# File names
files = ['Block_A.xlsx', 'Block_B.xlsx', 'Block_C.xlsx']
final_output_file = 'Final_output.xlsx'

# Load the 3 Excel files into DataFrames
dfs = [pd.read_excel(f) for f in files]

# Check for required columns
expected_columns = ['Customer Name', 'Number of Rooms', 'Type of Apartment']
for i, df in enumerate(dfs):
    if not all(col in df.columns for col in expected_columns):
        raise ValueError(f"File {files[i]} does not contain required columns.")

# Initialize output DataFrame
final_output = pd.DataFrame(columns=expected_columns)

while any(not df.empty for df in dfs):
    # Filter to only non-empty DataFrames
    non_empty_indices = [i for i, df in enumerate(dfs) if not df.empty]

    # Randomly select one of the non-empty files
    file_idx = random.choice(non_empty_indices)
    df = dfs[file_idx]

    # Randomly select one row from this DataFrame
    idx = random.choice(df.index)
    selected_row = df.loc[idx]

    # Append to final output
    final_output = pd.concat([final_output, selected_row.to_frame().T], ignore_index=True)

    # Remove selected row from source DataFrame
    dfs[file_idx] = df.drop(idx)

    print(f"Selected from {files[file_idx]}: {selected_row.to_dict()}")

# Save updated source files (after removals)
for i, df in enumerate(dfs):
    df.to_excel(files[i], index=False)

# Save final output file
final_output.to_excel(final_output_file, index=False)

print("Process complete. Final output saved in", final_output_file)
# Out:
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_C.xlsx: {'Customer Name': 'SEHER YALÇIN', 'Number of Rooms': 2, 'Type of Apartment': '2+1 1'}
# Selected from Block_C.xlsx: {'Customer Name': 'HÜSNÜ AYDINALP', 'Number of Rooms': 2, 'Type of Apartment': '2+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEDİME KOCA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'BAHADIR TIKNAS', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'AZİZ UĞUR ÇAĞLAR', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERDOĞAN KARALI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ELMIRA MADIYEVA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'VELİ BAYDUR', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'SEDA ÇERÇİZ VE ASİYE SERAP KARASULAR ', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ZELİHA ÇOŞKUN ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'BEYHAN SEZGİN', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'MAR USZ JAN DANAK', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEFER YALÇIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN LAÇİNER/MUSTA ÇELİK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'LEVENT AYHAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'ROZA JOWITA ORZEL', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KENAN YAKARIŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'ÇİĞDEM ÇAĞLAR', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ŞEFİK KOCAMAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'SİBEL ALGÜL', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'MAR USZ JAN DANAK', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'EYÜP GÜNEŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'ÖZTÜRK AVCI', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'İSMAİL HAKKI ÖNDER', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HICHAM HALLOU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERKAN KOÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'YASİN KOCAER', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'LALE DEMİRCİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'ÖZTÜRK AVCI', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'HATİCE OKÇU', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'MAR USZ JAN DANAK', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TALHA UMUT KILIÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'MEHRDAD RANJBAR', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_B.xlsx: {'Customer Name': 'SEHER YALÇIN', 'Number of Rooms': 1, 'Type of Apartment': '1+0 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'BEHÇET KAYA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SERHAT ESEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'İBRAHİM OFLAZOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MEHMET METE ÇALTULUOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HALİL GEÇİCİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MELİH CAN TOHUMCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KADİR TELKEŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MAR USZ JAN DANAK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MEHMET ALİ GÖKÇE', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'BURCU KÜLÇE', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ENDER ARSLAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MEHMET UĞUR ÖZEVİN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEMRA ATALAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HATİP ÖNEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HATİCE GÜLŞEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FAİK DEMİRKIR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜLYA EYÜP', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ORHAN ÇELİK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ZOREH TOLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'UMUT AKOVA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': ' YEŞİM HAVSA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SONGÜL KALENDER ÖYLÜ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HASAN KAYA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SAMİ BURAK KARAAHMETOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HATİCE GÜLŞEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NURAY ENEZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TAHİR UZUNAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SERAP KARAGÖL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEFER YALÇIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FARUK YILMAZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEHER YALÇIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ELİFE TENEKE', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FUAT MEMİŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÜMİT KUL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ELMIRA MADIYEVA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MEHMET ALİ GÖKÇE', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SONER TÜZÜN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEVDA KARADAĞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'OLENA SALNYKOVA/ORÇUN ÇİBUK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'İSMAİL UZUNAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MUSTAFA ARABACI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NAZLICAN TOLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SİNEM NUHOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'GERSON ERDEMANAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SERAP KARAGÖL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'BURHAN KAYA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MAR USZ JAN DANAK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'GÜVEN ATAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'JAROSLAW WOJCIECH', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'POLAT SAK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FATMA ZUHAL SARI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RASIM SULEYMANOV', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MUHAMMET ZAİD AKAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'GÖZDE YILMAZ ÇAMLI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ALPARSLAN ÖNDER', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'OLCAY ORUÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'CENGİZ KARKIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TANJU YILDIZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'AHMET GEÇİCİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DERYA KARAKURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'GERSON ERDEMANAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MUSTAFA SAMİ DEDEOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'EMİR TAHSİN KADEMOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FARUK YILMAZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MUSTAFA ONAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FATMA ZUHAL SARI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'BEŞİR AKBABA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'AMELİA KATAR ZYLA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN DURUL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'YAKUP GÜNGÖR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FATMA AKAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MÜGE ÖZER', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KALIYA TUTKUSHBAYEVA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEVGİ KOÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TAYFUN MEHMET KARAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ŞENOL ÇAKIR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'BEHÇET KAYA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERDİNÇ SÜMER', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'OKAN AYDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MEHMET EMİN HORASAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'AHMET GÜLŞEN VE ALEKS ALAKUŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'FATİH SALMAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'EBRU CANOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ORHAN ÇELİK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEHER YALÇIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ALİ CANER ÇATAK + ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KEMAL AYDIN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HAVVA SERAP TAŞKOYAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ORHAN YÜKSEL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ALİ USTA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MERVE ÇAKIR KILIÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KUDRET ÖZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERCAN GÖLPUNAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ZAFER KOÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'OKTAY ÇELİK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'CEMALEDDİN TOPAL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ENES KAYA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'EYÜP GÜNEŞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSNÜ AYDINALP', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ZEYNEP ARI ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HATİCE OKÇU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TUTKU ÇORBACI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DERVİŞ OZAN KARAKURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ZHANZIYA TUTKUSHBAYEVA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'İLKE DÜŞMEZ BENOİT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'YASİN KOCAER', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜLYA ASLAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HARUN AYDOĞDU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERAY ATAK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ABDULLAH ÇINAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KUDRET ÖZ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': ' YEŞİM HAVSA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN ÖZDEMİR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HARUN AYDOĞDU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ENDER ARSLAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'TAHİR UZUNAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'İSRAFİL TÜRK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ŞÜKRÜ ÇAPUR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HAYRETTİN YILDIRIM', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MELİH CAN TOHUMCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'AYFER ŞENOL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ASLI ERKENEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KADİRE SATI', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'REYHAN CANPOLAT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HATİCE GÜLŞEN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERDOĞAN GÜL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜSEYİN YEŞİLYURT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖMER YOLCU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HÜLYA YAŞLAR', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'EFKAN UCA', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RECEP ULUSOY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HARUN AYDOĞDU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HARUN AYDOĞDU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ERMAN KIRBEYGİRLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'HARUN AYDOĞDU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'RAHİME ONAY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'MUHAMMED CAN KOÇYİĞİT', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'PATRICK BALANGE', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEVDA KARADAĞ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'DELATTRE JEREMY', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'ÖZLEM CEYLAN', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'OKTAY ÇELİK', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'KADİR ERİKLİ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NEZİR ARAÇ', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'SEMA AKÇIL', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Selected from Block_A.xlsx: {'Customer Name': 'NESLİŞAH İSTENCİOĞLU', 'Number of Rooms': 1, 'Type of Apartment': '1+1 1'}
# Process complete. Final output saved in Final_output.xlsx

# %%
import pandas as pd

# Step 1: Load the Excel files
group_a = pd.read_excel("/content/Block_A.xlsx")
group_b = pd.read_excel("/content/Block_B.xlsx")

# Step 2: Keep first 141 rows in Group_A and move extra rows to Group_B
group_a_141 = group_a.iloc[:141]
extra_rows = group_a.iloc[141:]

# Step 3: Append extra rows to Group_B
group_b_updated = pd.concat([group_b, extra_rows], ignore_index=True)

# Step 4: Drop the existing 'FlatID' column from Group_B (if it exists)
if 'FlatID' in group_b_updated.columns:
    group_b_updated = group_b_updated.drop(columns=['FlatID'])

# Step 5: Add new FlatID column starting from 1
group_b_updated.insert(0, 'FlatID', range(1, len(group_b_updated) + 1))

# Step 6: Save the updated files
group_a_141.to_excel("Updated_Group_A.xlsx", index=False)
group_b_updated.to_excel("Updated_Group_B.xlsx", index=False)

print("✅ Updated_Group_A.xlsx and Updated_Group_B.xlsx have been saved with new FlatID column.")
# Out:
# ✅ Updated_Group_A.xlsx and Updated_Group_B.xlsx have been saved with new FlatID column.

# %%
import pandas as pd

def clean_flatid(df):
    # Remove old FlatID if exists and add new one
    if 'FlatID' in df.columns:
        df = df.drop(columns=['FlatID'])
    df.insert(0, 'FlatID', range(1, len(df) + 1))
    return df

# Step 1: Load the Excel files
group_a = pd.read_excel("/content/Block_A.xlsx")
group_b = pd.read_excel("/content/Block_B.xlsx")
group_c = pd.read_excel("/content/Block_C.xlsx")

# Step 2: Split Group A into first 140 and overflow
group_a_main = group_a.iloc[:140]
group_a_extra = group_a.iloc[140:]

# Step 3: Append extra from Group A to Group B
group_b_combined = pd.concat([group_b, group_a_extra], ignore_index=True)

# Step 4: Split Group B into first 140 and overflow
group_b_main = group_b_combined.iloc[:140]
group_b_extra = group_b_combined.iloc[140:]

# Step 5: Append extra from Group B to Group C
group_c_combined = pd.concat([group_c, group_b_extra], ignore_index=True)

# Step 6: Keep only 140 in each group
group_a_final = group_a_main
group_b_final = group_b_main
group_c_final = group_c_combined  # No limit needed unless you want to cap it too

# Step 7: Clean and add new FlatID columns
group_a_final = clean_flatid(group_a_final)
group_b_final = clean_flatid(group_b_final)
group_c_final = clean_flatid(group_c_final)

# Step 8: Save the updated Excel files
group_a_final.to_excel("Updated_Group_A.xlsx", index=False)
group_b_final.to_excel("Updated_Group_B.xlsx", index=False)
group_c_final.to_excel("Updated_Group_C.xlsx", index=False)

print("✅ Final files saved:\n- Updated_Group_A.xlsx\n- Updated_Group_B.xlsx\n- Updated_Group_C.xlsx")
# Out:
# ✅ Final files saved:
# - Updated_Group_A.xlsx
# - Updated_Group_B.xlsx
# - Updated_Group_C.xlsx
